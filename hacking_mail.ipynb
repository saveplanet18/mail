# %%
from bs4 import BeautifulSoup
import requests
import requests.exceptions
import urllib.parse
from collections import deque
import re


User_url=str(input('[+] kannur'))
urls=deque([User_url])

scraped_urls=set()
emails=set()


count=0
try:
    while len(urls):
        count+=1
        if count==100:
            break
        url=urls.popleft()
        scraped_urls.add(url)
        
        parts=urllib.parse.urlsplit(url)
        base_url='{0.scheme}://{0.netloc}'.format(parts)
    
        path=url[:url.rfind('/')+1] if '/' in parts.path else url
        print('%d proccssing %s'% (count,url))
        
        try:
            response=requests.get(url)
        except (requests.exceptions.MissingSchema,requests.exceptions.ConnectionError):
            continue
        new_emails=set(re.findall(r"[a-z0-9\.\-+ ]+@ [a-z0-9\.\-+]+\.[a-z]+",response.text,re.I))
        
        emails.update(new_emails)
        
        soup= BeautifulSoup(response.text,features='lxml')
        for anchor in soup.find_all("a"):
            link=anchor.attrs['href'] if 'href' in anchor.attrs else ''
            if link.startswith('/'):
                link=base_url+link
            elif not link.startswith('http'):
                link=path+link
            if not link in urls and not link in scraped_urls:
                urls.append(link)
                
except KeyboardInterrupt:
    print('[-] closing')
    
        
for mail in emails:
    print(mail)
# Out:
# [+] kannurhttps://www.netflix.com/in/
# 1 proccssing https://www.netflix.com/in/
# 2 proccssing https://www.netflix.com/login
# 3 proccssing https://www.netflix.com/in/tel:000-800-040-1843
# 4 proccssing https://help.netflix.com/support/412
# 5 proccssing https://help.netflix.com
# 6 proccssing https://www.netflix.com/youraccount
# 7 proccssing https://media.netflix.com/
# 8 proccssing http://ir.netflix.com/
# 9 proccssing https://jobs.netflix.com/jobs
# 10 proccssing https://www.netflix.com/watch
# 11 proccssing https://help.netflix.com/legal/termsofuse
# 12 proccssing https://help.netflix.com/legal/privacy
# 13 proccssing https://help.netflix.com/legal/privacy#cookies
# 14 proccssing https://help.netflix.com/legal/corpinfo
# 15 proccssing https://help.netflix.com/contactus
# 16 proccssing https://fast.com
# 17 proccssing https://help.netflix.com/legal/notices
# 18 proccssing https://www.netflix.com/in/browse/genre/839338
# 19 proccssing https://www.netflix.com/
# ...

# %%
import requests

# %%
s=requests.session()

# %%
payload={
    "Username":"maheshmeti10",
    "password":"kannurmsk3846",
}

response=s.post("https://www.instagram.com/maheshmeti10/",data=payload)
print(response.content)
